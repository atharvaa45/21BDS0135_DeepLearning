# %%
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from keras.datasets import mnist
from keras.models import Sequential
from keras.utils import to_categorical
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from keras.datasets import mnist
from keras.models import Sequential
from keras.utils import to_categorical

# %%
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# show a number from the dataset
plt.imshow(X_train[7])
plt.show()
print('Label: ', y_train[7])
# Out:
# Label:  3

# %%
X_train.shape,y_train.shape,X_test.shape,y_test.shape
# Out:
# ((60000, 28, 28), (60000,), (10000, 28, 28), (10000,))

# %%
X_train[0].shape
# Out:
# (28, 28)

# %%
X_train = X_train.reshape((X_train.shape[0], -1))
X_test = X_test.reshape((X_test.shape[0], -1))

# %%
X_train, _ , y_train, _=train_test_split(X_train,y_train,test_size=0.67,random_state=7)

# %%
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

print(X_train.shape, X_test.shape, y_train. shape, y_test.shape)
# Out:
# (19800, 784) (10000, 784) (19800, 10) (10000, 10)

# %%
from keras.models import Sequential
from keras. layers import Activation, Dense
from keras import optimizers

model = Sequential()

model.add(Dense(50, input_shape = (784, )))
model.add(Activation('sigmoid'))
model.add(Dense(50))
model.add(Activation('sigmoid'))
model.add(Dense(50))
model.add(Activation('sigmoid'))
model.add(Dense(50))
model.add(Activation('sigmoid'))
model.add(Dense(10))
model.add(Activation('softmax'))
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
sgd = optimizers.SGD(learning_rate= 0.001)
model. compile(optimizer = sgd, loss = 'categorical_crossentropy', metrics = ['accuracy'])

# %%
history = model.fit(X_train, y_train, batch_size = 256, validation_split = 0.3, epochs = 100, verbose = 0)

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.legend(['training', 'validation'], loc = 'upper left')
plt.show()

# %%
results = model.evaluate(X_test, y_test)
print('Test accuracy: ', results[1])
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.1160 - loss: 2.2998
# Test accuracy:  0.11349999904632568

# %%
def mlp_model():
  model = Sequential()

  model.add(Dense(50, input_shape = (784, ), kernel_initializer='he_normal'))
  model.add(Activation('sigmoid'))
  model.add(Dense(50, kernel_initializer='he_normal'))
  model.add(Activation('sigmoid'))
  model.add(Dense(50, kernel_initializer='he_normal'))
  model.add(Activation('sigmoid'))
  model.add(Dense(50, kernel_initializer='he_normal'))
  model.add(Activation('sigmoid'))
  model.add(Dense(10, kernel_initializer='he_normal'))
  model.add(Activation('softmax'))

  sgd = optimizers.SGD(learning_rate = 0.001)
  model. compile(optimizer = sgd, loss = 'categorical_crossentropy', metrics = ['accuracy'])

  return model

# %%
model = mlp_model()
history = model.fit(X_train, y_train, validation_split = 0.3, epochs = 100, verbose = 0)

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.legend( ['training', 'validation' ], loc = 'upper left')
plt.show()

# %%
results = model.evaluate(X_test, y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4237 - loss: 1.9512

# %%
print('Test accuracy: ', results[1])
# Out:
# Test accuracy:  0.4397999942302704

# %%
def mlp_model():
  model = Sequential()

  model.add(Dense(50, input_shape = (784, )))
  model.add(Activation('relu'))
  model.add(Dense(50))
  model.add(Activation('relu'))
  model.add(Dense(50))
  model.add(Activation('relu'))
  model.add(Dense(50))
  model.add(Activation('relu'))
  model.add(Dense(10))
  model.add(Activation('softmax'))

  sgd = optimizers.SGD(learning_rate = 0.001)
  model. compile(optimizer = sgd, loss = 'categorical_crossentropy', metrics = ['accuracy'])

  return model

model = mlp_model()
history = model.fit(X_train, y_train, validation_split = 0.3, epochs = 100, verbose = 0)

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.legend(['training', 'validation'], loc = 'upper left')
plt.show()

# %%
results = model.evaluate(X_test, y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9133 - loss: 0.5686

# %%
print('Test accuracy: ', results[1])
# Out:
# Test accuracy:  0.9240000247955322

# %%
def mlp_model():
  model = Sequential()

  model.add(Dense(50, input_shape = (784, )))
  model.add(Activation('elu'))
  model.add(Dense(50))
  model.add(Activation('elu'))
  model.add(Dense(50))
  model.add(Activation('elu'))
  model.add(Dense(50))
  model.add(Activation('elu'))
  model.add(Dense(10))
  model.add(Activation('softmax'))

  adam = optimizers.Adam(learning_rate = 0.001)
  model. compile(optimizer = adam, loss = 'categorical_crossentropy', metrics = ['accuracy'])

  return model

# %%
model = mlp_model()
history = model.fit(X_train, y_train, validation_split = 0.3, epochs = 100, verbose = 0)

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.legend(['training', 'validation'], loc = 'upper left')
plt.show()

# %%
results = model.evaluate(X_test, y_test)
print('Test accuracy: ', results[1])
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9446 - loss: 0.5461
# Test accuracy:  0.9520999789237976

# %%
from keras.layers import BatchNormalization

def mlp_model():
  model = Sequential()

  model.add(Dense(50, input_shape = (784, )))
  model.add(BatchNormalization())
  model.add(Activation('elu'))
  model.add(Dense(50))
  model.add(BatchNormalization())
  model.add(Activation('elu'))
  model.add(Dense(50))
  model.add(BatchNormalization())
  model.add(Activation('elu'))
  model.add(Dense(50))
  model.add(BatchNormalization())
  model.add(Activation('elu'))
  model.add(Dense(10))
  model.add(Activation('softmax'))

  adam = optimizers.Adam(learning_rate = 0.001)
  model. compile(optimizer = adam, loss = 'categorical_crossentropy', metrics = ['accuracy'])

  return model

# %%
model = mlp_model()
history = model.fit(X_train, y_train, validation_split = 0.3, epochs = 100, verbose = 0)

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.legend(['training', 'validation' ], loc = 'upper left')
plt.show()

# %%
results = model.evaluate(X_test, y_test)
print('Test accuracy: ', results[1])
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9554 - loss: 0.2093
# Test accuracy:  0.9639000296592712

# %%
from keras.layers import Dropout

# %%
def mlp_model():
  model = Sequential()

  model.add(Dense(50, input_shape = (784, )))
  model.add(Activation('elu'))
  model.add(Dropout(0.2))
  model.add(Dense(50))
  model.add(Activation('elu'))
  model.add(Dropout(0.2))
  model.add(Dense(50))
  model.add(Activation('elu'))
  model.add(Dropout(0.2))
  model.add(Dense(50))
  model.add(Activation('elu'))
  model.add(Dropout(0.2))
  model.add(Dense(10))
  model.add(Activation('softmax'))

  adam = optimizers.Adam(learning_rate = 0.001)
  model.compile(optimizer = adam, loss = 'categorical_crossentropy', metrics = ['accuracy'])

  return model

# %%
model = mlp_model()
history = model.fit(X_train, y_train, validation_split = 0.3, epochs = 100, verbose = 1)
# Out:
# Epoch 1/100
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.1502 - loss: 10.2739 - val_accuracy: 0.2837 - val_loss: 1.9197
# Epoch 2/100
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.2687 - loss: 2.0363 - val_accuracy: 0.4478 - val_loss: 1.4745
# Epoch 3/100
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.4096 - loss: 1.6444 - val_accuracy: 0.4976 - val_loss: 1.2912
# Epoch 4/100
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.4561 - loss: 1.4760 - val_accuracy: 0.5598 - val_loss: 1.1427
# Epoch 5/100
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.4942 - loss: 1.3765 - val_accuracy: 0.5850 - val_loss: 1.1027
# Epoch 6/100
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.5032 - loss: 1.3070 - val_accuracy: 0.5786 - val_loss: 1.0857
# Epoch 7/100
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.5284 - loss: 1.2387 - val_accuracy: 0.5877 - val_loss: 1.0711
# Epoch 8/100
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.5246 - loss: 1.2685 - val_accuracy: 0.5956 - val_loss: 0.9891
# Epoch 9/100
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.5432 - loss: 1.2037 - val_accuracy: 0.6359 - val_loss: 0.9173
# Epoch 10/100
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.5803 - loss: 1.1150 - val_accuracy: 0.6465 - val_loss: 0.8956
# Epoch 11/100
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.5984 - loss: 1.0598 - val_accuracy: 0.6386 - val_loss: 0.8929
# Epoch 12/100
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.5925 - loss: 1.0685 - val_accuracy: 0.6684 - val_loss: 0.8558
# Epoch 13/100
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.5991 - loss: 1.0563 - val_accuracy: 0.6995 - val_loss: 0.8196
# Epoch 14/100
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.6096 - loss: 1.0143 - val_accuracy: 0.6694 - val_loss: 0.9113
# Epoch 15/100
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6278 - loss: 1.0173 - val_accuracy: 0.7024 - val_loss: 0.7979
# Epoch 16/100
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6358 - loss: 0.9651 - val_accuracy: 0.6973 - val_loss: 0.8216
# Epoch 17/100
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.6266 - loss: 0.9939 - val_accuracy: 0.7199 - val_loss: 0.8048
# Epoch 18/100
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.6393 - loss: 0.9766 - val_accuracy: 0.6707 - val_loss: 0.8689
# Epoch 19/100
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.6663 - loss: 0.9208 - val_accuracy: 0.7392 - val_loss: 0.7657
# Epoch 20/100
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.6710 - loss: 0.9285 - val_accuracy: 0.7515 - val_loss: 0.7395
# Epoch 21/100
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.6761 - loss: 0.9011 - val_accuracy: 0.7591 - val_loss: 0.7094
# Epoch 22/100
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6873 - loss: 0.8972 - val_accuracy: 0.7123 - val_loss: 0.7810
# Epoch 23/100
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6757 - loss: 0.8956 - val_accuracy: 0.7495 - val_loss: 0.7119
# Epoch 24/100
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.6908 - loss: 0.8600 - val_accuracy: 0.7096 - val_loss: 0.7863
# Epoch 25/100
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6823 - loss: 0.8795 - val_accuracy: 0.7544 - val_loss: 0.7024
# Epoch 26/100
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.6741 - loss: 0.8699 - val_accuracy: 0.7672 - val_loss: 0.6685
# Epoch 27/100
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6973 - loss: 0.8180 - val_accuracy: 0.7766 - val_loss: 0.6216
# Epoch 28/100
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7218 - loss: 0.7830 - val_accuracy: 0.8074 - val_loss: 0.5855
# Epoch 29/100
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.7252 - loss: 0.7874 - val_accuracy: 0.7848 - val_loss: 0.6530
# Epoch 30/100
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7567 - loss: 0.7221 - val_accuracy: 0.8178 - val_loss: 0.5571
# Epoch 31/100
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7633 - loss: 0.6943 - val_accuracy: 0.8098 - val_loss: 0.5405
# Epoch 32/100
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.7732 - loss: 0.6831 - val_accuracy: 0.8483 - val_loss: 0.4871
# Epoch 33/100
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7788 - loss: 0.6669 - val_accuracy: 0.8328 - val_loss: 0.5353
# Epoch 34/100
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7748 - loss: 0.6756 - val_accuracy: 0.8753 - val_loss: 0.4540
# Epoch 35/100
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7826 - loss: 0.6615 - val_accuracy: 0.8924 - val_loss: 0.4158
# Epoch 36/100
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7946 - loss: 0.6300 - val_accuracy: 0.8960 - val_loss: 0.4184
# Epoch 37/100
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.7988 - loss: 0.6183 - val_accuracy: 0.8951 - val_loss: 0.4023
# Epoch 38/100
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8067 - loss: 0.5956 - val_accuracy: 0.8850 - val_loss: 0.4224
# Epoch 39/100
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.8031 - loss: 0.6031 - val_accuracy: 0.8938 - val_loss: 0.4101
# Epoch 40/100
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8160 - loss: 0.5792 - val_accuracy: 0.8758 - val_loss: 0.4395
# Epoch 41/100
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8112 - loss: 0.5907 - val_accuracy: 0.8992 - val_loss: 0.3750
# Epoch 42/100
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8187 - loss: 0.5738 - val_accuracy: 0.8953 - val_loss: 0.4081
# Epoch 43/100
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8171 - loss: 0.5890 - val_accuracy: 0.9022 - val_loss: 0.3877
# Epoch 44/100
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8249 - loss: 0.5557 - val_accuracy: 0.9020 - val_loss: 0.3928
# Epoch 45/100
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8278 - loss: 0.5497 - val_accuracy: 0.9101 - val_loss: 0.3693
# Epoch 46/100
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8327 - loss: 0.5290 - val_accuracy: 0.8944 - val_loss: 0.3980
# Epoch 47/100
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8211 - loss: 0.5613 - val_accuracy: 0.9010 - val_loss: 0.3811
# Epoch 48/100
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8274 - loss: 0.5495 - val_accuracy: 0.9138 - val_loss: 0.3599
# Epoch 49/100
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8326 - loss: 0.5371 - val_accuracy: 0.9152 - val_loss: 0.3603
# Epoch 50/100
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8291 - loss: 0.5301 - val_accuracy: 0.9113 - val_loss: 0.3537
# Epoch 51/100
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.8322 - loss: 0.5196 - val_accuracy: 0.9126 - val_loss: 0.3703
# Epoch 52/100
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8391 - loss: 0.5307 - val_accuracy: 0.9030 - val_loss: 0.3890
# Epoch 53/100
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8261 - loss: 0.5483 - val_accuracy: 0.9143 - val_loss: 0.3644
# Epoch 54/100
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8349 - loss: 0.5202 - val_accuracy: 0.9148 - val_loss: 0.3815
# Epoch 55/100
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8370 - loss: 0.5055 - val_accuracy: 0.9136 - val_loss: 0.3459
# Epoch 56/100
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.8340 - loss: 0.5234 - val_accuracy: 0.9008 - val_loss: 0.3730
# Epoch 57/100
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8297 - loss: 0.5325 - val_accuracy: 0.9077 - val_loss: 0.3789
# Epoch 58/100
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8478 - loss: 0.4907 - val_accuracy: 0.9019 - val_loss: 0.4146
# Epoch 59/100
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8418 - loss: 0.5148 - val_accuracy: 0.9180 - val_loss: 0.3662
# Epoch 60/100
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8450 - loss: 0.5016 - val_accuracy: 0.9116 - val_loss: 0.3696
# Epoch 61/100
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8367 - loss: 0.5145 - val_accuracy: 0.9120 - val_loss: 0.3601
# Epoch 62/100
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8363 - loss: 0.5088 - val_accuracy: 0.9029 - val_loss: 0.3704
# Epoch 63/100
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8391 - loss: 0.5150 - val_accuracy: 0.9177 - val_loss: 0.3586
# Epoch 64/100
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8441 - loss: 0.4702 - val_accuracy: 0.9136 - val_loss: 0.3566
# Epoch 65/100
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8354 - loss: 0.5106 - val_accuracy: 0.9163 - val_loss: 0.3395
# Epoch 66/100
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8389 - loss: 0.4908 - val_accuracy: 0.9222 - val_loss: 0.3200
# Epoch 67/100
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8370 - loss: 0.4919 - val_accuracy: 0.9173 - val_loss: 0.3583
# Epoch 68/100
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8468 - loss: 0.4775 - val_accuracy: 0.9168 - val_loss: 0.3348
# Epoch 69/100
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8427 - loss: 0.4969 - val_accuracy: 0.9116 - val_loss: 0.3461
# Epoch 70/100
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8530 - loss: 0.4601 - val_accuracy: 0.9158 - val_loss: 0.3572
# Epoch 71/100
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8532 - loss: 0.4582 - val_accuracy: 0.9182 - val_loss: 0.3334
# Epoch 72/100
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8559 - loss: 0.4532 - val_accuracy: 0.9163 - val_loss: 0.3369
# Epoch 73/100
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.8536 - loss: 0.4623 - val_accuracy: 0.9173 - val_loss: 0.3486
# Epoch 74/100
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.8576 - loss: 0.4465 - val_accuracy: 0.9157 - val_loss: 0.3166
# Epoch 75/100
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8632 - loss: 0.4387 - val_accuracy: 0.9184 - val_loss: 0.3365
# Epoch 76/100
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8511 - loss: 0.4541 - val_accuracy: 0.9217 - val_loss: 0.3380
# Epoch 77/100
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8524 - loss: 0.4665 - val_accuracy: 0.9187 - val_loss: 0.3400
# Epoch 78/100
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8578 - loss: 0.4668 - val_accuracy: 0.9199 - val_loss: 0.3396
# Epoch 79/100
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8609 - loss: 0.4325 - val_accuracy: 0.9232 - val_loss: 0.3293
# Epoch 80/100
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.8540 - loss: 0.4541 - val_accuracy: 0.9116 - val_loss: 0.3673
# Epoch 81/100
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8580 - loss: 0.4407 - val_accuracy: 0.9210 - val_loss: 0.3157
# Epoch 82/100
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8678 - loss: 0.4253 - val_accuracy: 0.9145 - val_loss: 0.3612
# Epoch 83/100
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8559 - loss: 0.4508 - val_accuracy: 0.9184 - val_loss: 0.3205
# Epoch 84/100
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8607 - loss: 0.4481 - val_accuracy: 0.9199 - val_loss: 0.3224
# Epoch 85/100
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8642 - loss: 0.4480 - val_accuracy: 0.9194 - val_loss: 0.3253
# Epoch 86/100
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8598 - loss: 0.4401 - val_accuracy: 0.9136 - val_loss: 0.3557
# Epoch 87/100
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8564 - loss: 0.4609 - val_accuracy: 0.9172 - val_loss: 0.3292
# Epoch 88/100
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8631 - loss: 0.4309 - val_accuracy: 0.9157 - val_loss: 0.3272
# Epoch 89/100
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8589 - loss: 0.4301 - val_accuracy: 0.9135 - val_loss: 0.3408
# Epoch 90/100
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8555 - loss: 0.4521 - val_accuracy: 0.9217 - val_loss: 0.3496
# Epoch 91/100
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8610 - loss: 0.4293 - val_accuracy: 0.9215 - val_loss: 0.3256
# Epoch 92/100
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8652 - loss: 0.4366 - val_accuracy: 0.9258 - val_loss: 0.3534
# Epoch 93/100
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8693 - loss: 0.4216 - val_accuracy: 0.9133 - val_loss: 0.3952
# Epoch 94/100
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8620 - loss: 0.4395 - val_accuracy: 0.9178 - val_loss: 0.3410
# Epoch 95/100
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8661 - loss: 0.4142 - val_accuracy: 0.9222 - val_loss: 0.3200
# Epoch 96/100
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8626 - loss: 0.4343 - val_accuracy: 0.9253 - val_loss: 0.3356
# Epoch 97/100
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8584 - loss: 0.4343 - val_accuracy: 0.9157 - val_loss: 0.3365
# Epoch 98/100
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8610 - loss: 0.4460 - val_accuracy: 0.9263 - val_loss: 0.3169
# Epoch 99/100
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8654 - loss: 0.4216 - val_accuracy: 0.9160 - val_loss: 0.3592
# Epoch 100/100
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8638 - loss: 0.4366 - val_accuracy: 0.9101 - val_loss: 0.3678

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.legend(['training', 'validation'], loc='upper left')
plt.show()

# %%
results = model.evaluate(X_test, y_test)
print('Test accuracy: ', results[1])
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8937 - loss: 0.4469
# Test accuracy:  0.9092000126838684
